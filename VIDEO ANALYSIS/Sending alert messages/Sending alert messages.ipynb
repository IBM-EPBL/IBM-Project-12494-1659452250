# %%
pip install twilio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.4 MB 12.3 MB/s
# ...

# %%
pip install playsound
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7035 sha256=10eda8d91d4badd11a4c4fda9733b15a6b7044899d7726b9086c8507190cbd34
#   Stored in directory: /root/.cache/pip/wheels/ba/f8/bb/ea57c0146b664dca3a0ada4199b0ecb5f9dfcb7b7e22b65ba2
# Successfully built playsound
# ...

# %%
pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import keras
import tensorflow as tf

# %%
import cv2
import numpy as np
from keras.preprocessing import image
from keras.models import load_model
from twilio.rest import Client
from playsound import playsound
# Out:
# WARNING:playsound:playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.

# %%
from pydub import AudioSegment
from pydub.playback import play

# %%
from google.colab.patches import cv2_imshow

# %%
model=load_model(r'/content/drive/MyDrive/forestfire.h5')
video=cv2.VideoCapture("/content/drive/MyDrive/Forest Fire - 93861.mp4")
name=['forest','with forest']

# %%
while(1):
  success, frame=video.read()
  cv2.imwrite("image1.jpg", frame)
  img=keras.utils.load_img("image1.jpg", target_size=(128,128))
  x=keras.utils.img_to_array(img)
  x=np.expand_dims(x,axis=0)
  pred=model.predict(x)
  p=pred[0]
  print(pred)
# Out:
# 1/1 [==============================] - 0s 355ms/step
# [[1.]]
# 1/1 [==============================] - 0s 35ms/step
# [[1.]]
# 1/1 [==============================] - 0s 37ms/step
# [[1.]]
# 1/1 [==============================] - 0s 40ms/step
# [[1.]]
# 1/1 [==============================] - 0s 43ms/step
# [[1.]]
# 1/1 [==============================] - 0s 37ms/step
# [[1.]]
# 1/1 [==============================] - 0s 39ms/step
# [[1.]]
# 1/1 [==============================] - 0s 39ms/step
# [[1.]]
# 1/1 [==============================] - 0s 41ms/step
# [[1.]]
# 1/1 [==============================] - 0s 42ms/step
# [[1.]]
# 1/1 [==============================] - 0s 41ms/step
# [[1.]]
# 1/1 [==============================] - 0s 39ms/step
# [[1.]]
# 1/1 [==============================] - 0s 36ms/step
# [[1.]]
# 1/1 [==============================] - 0s 37ms/step
# [[1.]]
# 1/1 [==============================] - 0s 38ms/step
# [[1.]]
# 1/1 [==============================] - 0s 39ms/step
# ...

# %% [markdown]
# Error occured as the video ended...

# %%
  pred = model.predict(x)
  if pred[0]==1:
    account_sid = 'ACff1bf8e870b4b3af4ccdfe1e91b3842e'
    auth_token = '3eb9c1342edc25b81ab9b736b45f754d'
    client = Client(account_sid, auth_token)

    message = client.messages \
        .create(
            body='Alert: Forest fire is detected!!',
            from_=' +14793973433',
            to='+918940861869'
        )

    print(message)
    print('Fire Detected')
    print ('SMS sent!')
    song=AudioSegment.from_mp3('/content/drive/MyDrive/Siren.mp3')
    print('playing alarm song')
    play(song)

  else:
    print("No Danger") 

video.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 41ms/step
# SMa3cf62847c585d596a7af8f9c26c5f53
# Fire Detected
# SMS sent!
# playing alarm song
